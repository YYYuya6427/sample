# %%
# APIからデータを取得するコード
import requests
import pandas as pd
from io import BytesIO

url = "http://localhost:8000/api/export_app"
params = {"app": "questionnaire"}
headers = {
    "Authorization": "Token YOUR_API_TOKEN"
}
"""
実際に実験する際はサーバーにurlを上げる→データ取得する際にトークン（パスワードのようなもの）求められる
Token情報を追加しておくことで、認証を通過できる
"""

r = requests.get(url, params=params, headers=headers)
"""
パラメータのurlを個別に取得すると、一文字でも間違えると動かない
そこで、getメソッドを用いてURL全体を取得する（get内部でパラメータをそれぞれ設定）
"""
print(f"URL requested: {r.url}")
r.raise_for_status()

df = pd.read_csv(BytesIO(r.content))

with open("questionnaire.csv", "wb") as f:
    f.write(r.content)
# Out:
# URL requested: http://localhost:8000/api/export_app?app=questionnaire

# %%
df
# Out:
#    participant.id_in_session participant.code  participant.label  \
# 0                          1         6w1h4kun                NaN
# 1                          1         lnsn0ikd                NaN
# 2                          1         1epzg6ri                NaN
# 3                          1         w1d5bc7s                NaN
# 4                          1         s50wlj7k                NaN
# 5                          1         ak52lpof                NaN
#
#    participant._is_bot  participant._index_in_pages  \
# 0                    0                            2
# 1                    0                            0
# 2                    0                            1
# 3                    0                            2
# 4                    0                            2
# 5                    0                            0
#
#    participant._max_page_index participant._current_app_name  \
# 0                            1                 questionnaire
# ...
